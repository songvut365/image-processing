# %%
# %matplotlib inline

import numpy as np
import pandas as pd 
from skimage import io, color
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

PATH = "/content/drive/MyDrive/KMITL/ปี 3 เทอม 2/Image Processing/anime_faces/data/"

# %% [markdown]
# UTILS

# %%
def display(img):
    plt.figure()
    plt.set_cmap('gray')
    plt.imshow(img)
    plt.show()


def combineLAB(l, a, b):
    shape = (l.shape[0], l.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = l
    zeros[:, :, 1] = a
    zeros[:, :, 2] = b
    return zeros


def combineAB(a, b):
    shape = (a.shape[0], b.shape[1], 2)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = a
    zeros[:, :, 1] = b
    return zeros


def combineL_AB(l, ab):
    shape = (l.shape[0], l.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = l
    zeros[:, :, 1] = ab[:, :, 0]
    zeros[:, :, 2] = ab[:, :, 1]
    return zeros


def make3channels(gray):
    shape = (gray.shape[0], gray.shape[1], 3)
    zeros = np.zeros(shape)
    zeros[:, :, 0] = gray
    zeros[:, :, 1] = gray
    zeros[:, :, 2] = gray
    return zeros


def get_l_from_gray(img_path):
    img = io.imread(img_path)
    gray = color.rgb2gray(img)
    gray = make3channels(gray)
    lgray = color.rgb2lab(gray, illuminant='D50')[:, :, 0]
    return lgray


def get_ab_from_file(file):
    img = io.imread(file)
    ab = np.zeros((64, 64, 2))
    ab[:, :, 0] = img[:, :, 1]
    ab[:, :, 1] = img[:, :, 2]
    return ab


def lab_normal_image(path):
    l, ab = load_img_for_training(path)
    l, ab = (l-127.5)/127.5, (ab-127.5)/127.5
    return l, ab


def rgb_image(l, ab):
    l, ab = l*127.5 + 127.5, (ab*127.5)+127.5
    lab = combineL_AB(l, ab)
    rgb = color.lab2rgb(lab, illuminant='D50')
    return rgb


def load_img_for_training(img_path):
    img = io.imread(img_path)
    lab = color.rgb2lab(img, illuminant='D50')
    l, a, b = lab[:, :, 0], lab[:, :, 1], lab[:, :, 2]
    ab = combineAB(a, b)
    lgray = get_l_from_gray(img_path)
    return lgray, ab


def save_ab_file(image, filepath):
    # add in 0zeros to its first component
    shape = (image.shape[0], image.shape[1], 3)
    new_ab_image = np.zeros(shape)
    new_ab_image[:, :, 1] = image[:, :, 0]
    new_ab_image[:, :, 2] = image[:, :, 1]
    save_file(new_ab_image, filepath)


def save_file(image, filepath):
    io.imsave(filepath, image)


def load_ab_image(path):
    img = io.imread(path)
    shape = (img.shape[0], img.shape[1], 2)
    ab = np.zeros(shape)
    ab[:, :, 0] = img[:, :, 1]
    ab[:, :, 1] = img[:, :, 2]
    return ab

# %% [markdown]
# Data Loading

# %%
def get_data(path):
    start = 1
    end = 18000

    x_data = np.zeros((18000, 64, 64))
    y_data = np.zeros((18000, 64, 64, 2))

    for i in range(start, end+1):
        filename = path + str(i) + ".png"
        l, ab = lab_normal_image(filename)
        x_data[i-1] = l
        y_data[i-1] = ab

    return x_data, y_data

x_data,y_data = get_data(PATH)
print("X SHAPE:",x_data.shape)
print("Y SHAPE:",y_data.shape)
# Out:
# X SHAPE: (18000, 64, 64)
# Y SHAPE: (18000, 64, 64, 2)

# %%
l_sample,ab_sample = x_data[3],y_data[3]
rgb_sample = rgb_image(l_sample,ab_sample)
display(rgb_sample)
display(l_sample)

# %% [markdown]
# GAN Architect

# %%
from keras import *
from keras.layers import *
from keras.activations import *
from keras.optimizers import *
from matplotlib import pyplot as plt
# from utils import *
from keras.initializers import RandomNormal, Zeros

# %% [markdown]
# Using TensorFlow backend.

# %%
def residual_block(feature, dropout=False):
    x = Conv2D(256, kernel_size=3, strides=1, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if dropout:
        x = Dropout(0.5)(x)
    x = Conv2D(256, kernel_size=3, strides=1, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return Add()([feature, x])


def conv_block(feature, out_channel, downsample=True, dropout=False):
    if downsample:
        x = Conv2D(out_channel, kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(
            mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    else:
        x = Conv2DTranspose(out_channel, kernel_size=4, strides=2, padding='same', kernel_initializer=RandomNormal(
            mean=0.0, stddev=0.02), bias_initializer=Zeros())(feature)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    if dropout:
        x = Dropout(0.5)(x)
    return x


def build_model(n_block=5):
    image_size = 64
    input_channel = 1
    output_channel = 2
    input = Input(shape=(image_size, image_size, input_channel))
    x = Conv2D(64, kernel_size=7, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(input)  # use reflection padding instead
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # downsample
    x = Conv2D(128, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # downsample
    x = Conv2D(256, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    for i in range(n_block):
        x = residual_block(x)
    # upsample
    x = Conv2DTranspose(128, kernel_size=3, strides=2, padding='same',
                        kernel_initializer=RandomNormal(mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # upsample
    x = Conv2DTranspose(64, kernel_size=3, strides=2, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # out
    x = Conv2D(output_channel, kernel_size=7, padding='same', kernel_initializer=RandomNormal(
        mean=0.0, stddev=0.02), bias_initializer=Zeros())(x)  # use reflection padding instead
    x = BatchNormalization()(x)
    x = Activation('tanh')(x)
    model = Model(inputs=input, outputs=x)
    model.summary()
    return model

def save_images(generator, samples):
    ab_values = generator.predict(samples)
    plt.figure(figsize=(12, 12))
    plt.suptitle("Colorize Anime Faces")
    plt.gcf()
    plt.set_cmap('gray')
    for i in range(ab_values.shape[0]):
        l_val = samples[i][:,:,0]
        ab_val = ab_values[i]
        rgb = rgb_image(l_val, ab_val)
        ax = plt.subplot(4, 4, i+1)
        im = ax.imshow(rgb)
    plt.draw()
    plt.savefig('gan_generated_image.png', dpi=100)
    plt.show()


    
def train_network(x_data,y_data,epochs=100, batch_size=128, save_interval=5):
    input_shape = (64, 64, 1)
    output_shape = (64, 64, 2)
    model = build_model()
    model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
    history = model.fit(x_data,y_data,validation_split=0.1,epochs=epochs,batch_size=128,)
    model.save('model.h5')
    print("MODEL SAVED")
    return model, history

# %%
x_data = x_data.reshape((18000,64,64,1))
model=train_network(x_data,y_data,epochs=32)


# Use model file
# from keras.models import load_model
# model = load_model('/content/drive/MyDrive/KMITL/ปี 3 เทอม 2/Image Processing/anime_faces_model.h5')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 64, 64, 1)]  0           []
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   3200        ['input_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 128)  73856       ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 256)  295168      ['activation_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_20[0][0]']
#
#  add_5 (Add)                    (None, 16, 16, 256)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 256)  590080      ['add_5[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_22[0][0]']
#
#  add_6 (Add)                    (None, 16, 16, 256)  0           ['add_5[0][0]',
#                                                                   'activation_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 256)  590080      ['add_6[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_24[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 256)  0           ['add_6[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 256)  590080      ['add_7[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_26[0][0]']
#
#  add_8 (Add)                    (None, 16, 16, 256)  0           ['add_7[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 256)  590080      ['add_8[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_28[0][0]']
#
#  add_9 (Add)                    (None, 16, 16, 256)  0           ['add_8[0][0]',
#                                                                   'activation_28[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 32, 32, 128)  295040     ['add_9[0][0]']
#  spose)
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 128)  512        ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 64)  73792       ['activation_29[0][0]']
#  spose)
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 64)  256         ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_30[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 2)    6274        ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 2)   8           ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 2)    0           ['batch_normalization_31[0][0]']
#
# ==================================================================================================
# Total params: 6,660,938
# Trainable params: 6,654,534
# Non-trainable params: 6,404
# __________________________________________________________________________________________________
# Epoch 1/32
# 127/127 [==============================] - 78s 598ms/step - loss: 0.0124 - mse: 0.0124 - mae: 0.0339 - val_loss: 7.5058e-04 - val_mse: 7.5058e-04 - val_mae: 0.0098
# Epoch 2/32
# 127/127 [==============================] - 75s 591ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0063 - val_loss: 2.7319e-04 - val_mse: 2.7319e-04 - val_mae: 0.0123
# Epoch 3/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0043 - val_loss: 0.0011 - val_mse: 0.0011 - val_mae: 0.0158
# Epoch 4/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0034 - val_loss: 0.0040 - val_mse: 0.0040 - val_mae: 0.0223
# Epoch 5/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0032 - val_loss: 0.0741 - val_mse: 0.0741 - val_mae: 0.1287
# Epoch 6/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0040 - val_loss: 0.0088 - val_mse: 0.0088 - val_mae: 0.0298
# Epoch 7/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0032 - val_loss: 0.0015 - val_mse: 0.0015 - val_mae: 0.0145
# Epoch 8/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0054 - val_loss: 1.1614e-04 - val_mse: 1.1614e-04 - val_mae: 0.0101
# Epoch 9/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0030 - val_loss: 1.0501e-04 - val_mse: 1.0501e-04 - val_mae: 0.0096
# Epoch 10/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0031 - val_loss: 7.4228e-05 - val_mse: 7.4228e-05 - val_mae: 0.0080
# Epoch 11/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0025 - val_loss: 8.9425e-05 - val_mse: 8.9425e-05 - val_mae: 0.0089
# Epoch 12/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0028 - val_loss: 8.9335e-05 - val_mse: 8.9335e-05 - val_mae: 0.0089
# Epoch 13/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0030 - val_loss: 8.7521e-05 - val_mse: 8.7521e-05 - val_mae: 0.0080
# Epoch 14/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0023 - val_loss: 9.2489e-05 - val_mse: 9.2489e-05 - val_mae: 0.0085
# Epoch 15/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0029 - val_loss: 1.1024e-04 - val_mse: 1.1024e-04 - val_mae: 0.0090
# Epoch 16/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0028 - val_loss: 9.0928e-05 - val_mse: 9.0928e-05 - val_mae: 0.0087
# Epoch 17/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0028 - val_loss: 9.1444e-05 - val_mse: 9.1444e-05 - val_mae: 0.0088
# Epoch 18/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0033 - val_loss: 9.8282e-05 - val_mse: 9.8282e-05 - val_mae: 0.0083
# Epoch 19/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0029 - val_loss: 9.4976e-05 - val_mse: 9.4976e-05 - val_mae: 0.0083
# Epoch 20/32
# 127/127 [==============================] - 75s 590ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0021 - val_loss: 1.0532e-04 - val_mse: 1.0532e-04 - val_mae: 0.0090
# Epoch 21/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0031 - val_loss: 1.1508e-04 - val_mse: 1.1508e-04 - val_mae: 0.0084
# Epoch 22/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0025 - val_loss: 1.4693e-04 - val_mse: 1.4693e-04 - val_mae: 0.0094
# Epoch 23/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0038 - val_loss: 2.7171e-04 - val_mse: 2.7171e-04 - val_mae: 0.0094
# Epoch 24/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0027 - val_loss: 2.0263e-04 - val_mse: 2.0263e-04 - val_mae: 0.0084
# Epoch 25/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0027 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0236
# Epoch 26/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0024 - val_loss: 6.2590e-04 - val_mse: 6.2590e-04 - val_mae: 0.0116
# Epoch 27/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0027 - val_loss: 0.0013 - val_mse: 0.0013 - val_mae: 0.0158
# Epoch 28/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0023 - val_loss: 9.5558e-04 - val_mse: 9.5558e-04 - val_mae: 0.0133
# Epoch 29/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0031 - val_loss: 0.0619 - val_mse: 0.0619 - val_mae: 0.1150
# Epoch 30/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0037 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0291
# Epoch 31/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0028 - val_loss: 0.0657 - val_mse: 0.0657 - val_mae: 0.1154
# Epoch 32/32
# 127/127 [==============================] - 75s 589ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0024 - val_loss: 0.0511 - val_mse: 0.0511 - val_mae: 0.0968
# MODEL SAVED

# %% [markdown]
# Plot

# %%
fig = plt.figure(figsize=(15, 4))
fig.suptitle("History")
rows = 1
cols = 3

fig.add_subplot(rows, cols, 1)
plt.plot(model[1].history['loss'], label="loss")
plt.plot(model[1].history['val_loss'], label="val_loss")
plt.title("LOSS")
plt.ylim([-0.05, 0.5])
plt.legend()

fig.add_subplot(rows, cols, 2)
plt.plot(model[1].history['mse'], label="mse")
plt.plot(model[1].history['val_mse'], label="val_mse")
plt.title("MSE")
plt.ylim([-0.05, 0.5])
plt.legend()

fig.add_subplot(rows, cols, 3)
plt.plot(model[1].history['mae'], label="mae")
plt.plot(model[1].history['val_mae'], label="val_mae")
plt.title("MAE")
plt.ylim([-0.05, 0.5])
plt.legend()

plt.show()

# %% [markdown]
# Show result

# %%
samples = x_data[0:10]
save_images(model[0],samples)

# %%
plt.figure(figsize=(12, 12))
plt.suptitle("Gray Anime Faces")

for i in range(len(samples)):
  plt.set_cmap('gray')
  ax = plt.subplot(4, 4, i+1)
  img = samples[i]
  im = ax.imshow(img[:, :, 0])
plt.show()
